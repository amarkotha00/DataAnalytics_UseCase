# %% [markdown]
# ## **Name : Amar Kotha**

# %% [markdown]
# ***The Sparks Foundation***
#
# *Task 03 : Exploratory Data Analysis on a Sample SuperStore Dataset*

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/SampleSuperstore.xls')

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country  ... Quantity Discount   Profit
# 9989    Second Class  Consumer  United States  ...        3      0.2   4.1028
# 9990  Standard Class  Consumer  United States  ...        2      0.0  15.6332
# 9991  Standard Class  Consumer  United States  ...        2      0.2  19.3932
# 9992  Standard Class  Consumer  United States  ...        4      0.0  13.3200
# 9993    Second Class  Consumer  United States  ...        2      0.0  72.9480
#
# [5 rows x 13 columns]

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#unique values

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# There are no null Values in the data Set

# %% [markdown]
# Drop the redundant data

# %%
corelation=data.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns
            ,annot=True)

# %%
sns.pairplot(data)

# %%
sns.set_style("whitegrid")
sns.pairplot(data,hue="Region",palette="bwr")

# %%
segment=data.Segment.value_counts().reset_index()
segment.columns=("Segment","Count")
segment
# Out:
#        Segment  Count
# 0     Consumer   5191
# 1    Corporate   3020
# 2  Home Office   1783

# %%
#Pie chart

# %%
plt.pie(x="Count",labels="Segment",data=segment,radius=2,pctdistance=0.4)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f50837ed910>,
# ...
#  [Text(-0.13408036713364035, 2.1959103932422446, 'Consumer'),
#   Text(-1.0537686579632295, -1.9312098838537397, 'Corporate'),
#   Text(1.8633972391176687, -1.1695087555245793, 'Home Office')])

# %%
plt.figure(figsize=(9,5))
plt.title("Categories and Regions")
sns.countplot(x=data['Category'],hue=data['Region'],palette='rocket')
plt.xticks()
# Out:
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)

# %%
data.Sales.max()
# Out:
# 22638.48

# %%
data.Sales.min()
# Out:
# 0.444

# %% [markdown]
# We can see that Profit is affected by Sales and Discount
